# %% [markdown]
# # Web Scraping Tutorial
#
# This notebook provides a step-by-step guide to scrape data from a website. Web scraping is a technique used to extract information from websites by transforming the data on web pages into a structured format. This is particularly useful for data analysis, machine learning, and other data-driven tasks.
#
# In this tutorial, we will walk through the process of scraping product information from a sample e-commerce site. By following these steps, you will learn how to:
#
# 1. Send HTTP requests to retrieve web pages.
# 2. Parse HTML content using BeautifulSoup.
# 3. Identify and extract relevant data elements from the parsed HTML.
# 4. Store the extracted data in a structured format using pandas.
# 5. Save the data to a CSV file.
# 6. Optionally, save the data to a database such as MongoDB.
#
# The website we will be scraping is [ScrapeMe](https://scrapeme.live/shop/). This site is designed for practice purposes and contains a variety of products with details such as names and prices, which makes it an ideal candidate for learning web scraping techniques.
#
# Before you begin, please visit the site to understand its structure. This will help you identify the elements you need to scrape.
#
# Let's get started!

# %% [markdown]
# ## Import libraries here

# %%
import requests
import bs4
import pandas as pd

# %% [markdown]
# ## Step 1: Send a request to the website

# %%
url = 'https://scrapeme.live/shop/'

response = requests.get(url)
print(response.text[:500])
# Out:
# <!doctype html>
# <html lang="en-GB">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=2.0">
# <link rel="profile" href="http://gmpg.org/xfn/11">
# <link rel="pingback" href="https://scrapeme.live/xmlrpc.php">
#
# <title>Products &#8211; ScrapeMe</title>
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="ScrapeMe &raquo; Feed" href="ht

# %% [markdown]
# ## Step 2: Parse the HTML content of the page

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html.parser')

print(soup.title.text)
# Out:
# Products – ScrapeMe

# %% [markdown]
# ## Step 3: Extract the desired data

# %%
# name of priducts
products = soup.find_all('h2', attrs={"class": "woocommerce-loop-product__title"})

for product in products:
  print(product.text)

print(len(products))
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# Charmander
# Charmeleon
# Charizard
# Squirtle
# Wartortle
# Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# Pidgey
# 16

# %%
prices = soup.find_all('span', attrs={"class" : "woocommerce-Price-amount amount"})

for price in prices:
  print(price.text)

print(len(prices))
# Out:
# £0.00
# £63.00
# £87.00
# £105.00
# £48.00
# £165.00
# £156.00
# £130.00
# £123.00
# £76.00
# £73.00
# £148.00
# £162.00
# £25.00
# £148.00
# £168.00
# £159.00
# 17

# %% [markdown]
# ## Step 4: Create a DataFrame to store the extracted data

# %%
extracted_data = {
    'product_name': [],
    'price': []
}

for product in products:
  extracted_data['product_name'].append(product.text)

for price in prices:
  extracted_data['price'].append(price.text)

# Remove the first element from the 'price' list
if extracted_data['price']:
    extracted_data['price'].pop(0)


extracted_data = pd.DataFrame(extracted_data)
extracted_data
# Out:
#    product_name    price
# 0     Bulbasaur   £63.00
# 1       Ivysaur   £87.00
# 2      Venusaur  £105.00
# 3    Charmander   £48.00
# 4    Charmeleon  £165.00
# 5     Charizard  £156.00
# 6      Squirtle  £130.00
# 7     Wartortle  £123.00
# 8     Blastoise   £76.00
# 9      Caterpie   £73.00
# 10      Metapod  £148.00
# 11   Butterfree  £162.00
# 12       Weedle   £25.00
# 13       Kakuna  £148.00
# 14     Beedrill  £168.00
# 15       Pidgey  £159.00

# %% [markdown]
# ## Step 5: Save the data to a CSV file

# %%
extracted_data.to_csv('extracted_data.csv', index=False)

# %% [markdown]
# ## Step 6: Print the DataFrame to verify the extracted data

# %%
extracted_data
# Out:
#    product_name    price
# 0     Bulbasaur   £63.00
# 1       Ivysaur   £87.00
# 2      Venusaur  £105.00
# 3    Charmander   £48.00
# 4    Charmeleon  £165.00
# 5     Charizard  £156.00
# 6      Squirtle  £130.00
# 7     Wartortle  £123.00
# 8     Blastoise   £76.00
# 9      Caterpie   £73.00
# 10      Metapod  £148.00
# 11   Butterfree  £162.00
# 12       Weedle   £25.00
# 13       Kakuna  £148.00
# 14     Beedrill  £168.00
# 15       Pidgey  £159.00

# %% [markdown]
# ## Step 7: Save the data to a database of your choice. If you are using MongoDB, include the code here.

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.2 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 18.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.8.0

# %%
import pymongo
from pymongo import MongoClient
import os

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://haya6000:Haya1234@cluster3.qlt9k1t.mongodb.net/?retryWrites=true&w=majority&appName=Cluster3"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Create a database
db = client['extracted_data']

# Create a collection
products_collection = db['pdudocts']

# %%
products_collection = db['pdudocts'].insert_many(extracted_data.to_dict('records'))
